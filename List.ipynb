# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiKiranGandham/SaiKiran-PythonFS/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program to create a list of 5 integers and print it
list = [ 1, 2, 3, 4, 5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Write a program to print the first and last elements of a list
list = [10, 20, 30, 40, 50]
print(list[0], list[-1])
# Out:
# 10 50

# %%
#Write a program to add an element to the end of a list using append()
list = [10, 20, 30, 40, 50]
list.append(80)
print(list)
# Out:
# [10, 20, 30, 40, 50, 80]

# %%
#Write a program to insert an element at a specific position in a list
list = [10, 20, 30, 40, 50]
list.insert(3, 90)
print(list)
# Out:
# [10, 20, 30, 90, 40, 50]

# %%
#Write a program to remove an element from a list using remove()
list = [10, 20, 30, 40, 50, 60]
list.remove(50)
print(list)
# Out:
# [10, 20, 30, 40, 60]

# %%
#Write a program to check whether an element exists in a list
list = [10, 20, 30, 40, 50, 60]
if 50 in list:
    print("Element exists in the list")
else:
    print("Element does not exist in the list")
# Out:
# Element exists in the list

# %%
list = [10, 20, 30, 40, 50, 60]
print(len(list))
# Out:
# 6

# %%
#Write a program to count how many times an element appears in a list
list = [10, 20, 30, 50, 30, 50, 40, 50]
count = list.count(50)
print(count)
# Out:
# 3

# %%
#Write a program to find the index of an element in a list
list = [10, 20, 30, 40, 50, 90]
print(list[5])
# Out:
# 90

# %%
#Write a program to reverse a list
list = [10, 20, 30, 40, 60, 80]
list.reverse()
print(list)
# Out:
# [80, 60, 40, 30, 20, 10]
