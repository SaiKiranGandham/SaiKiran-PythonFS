# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiKiranGandham/SaiKiran-PythonFS/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create a variable name and store your name in it. Print it
name = "sai kiran"
print(name)
# Out:
# sai kiran

# %%
#Create a variable age and store your age. print it
age = 22
print(age)
# Out:
# 22

# %%
#Store the value 100 in a variable num. Print the variable
num = 100
print(num)
# Out:
# 100

# %%
#Create two variables a = 10 and b = 20. Print their sum
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
#Create a variable city and store your city name
city = "Hyderabad"
print(city)
# Out:
# Hyderabad

# %% [markdown]
# **Combined Program**

# %%
name = "Sai Kiran"
age = 22
num = 100
a = 10
b = 20
city = "hyderabad"
print(name)
print(age)
print(num)
print(a + b)
print(city)
# Out:
# Sai Kiran
# 22
# 100
# 30
# hyderabad

# %%
#Store your first name and last name in separate variables and print the full name
first_name = "Sai Kiran"
last_name = "Naidu"
print(first_name + " " + last_name)
# Out:
# Sai Kiran Naidu

# %%
#Create variables length = 5 and width = 4. Find the area of a rectangle
length = 5
width = 4
area = length * width
print("area of rectangle=", area)
# Out:
# area of rectangle= 20

# %%
#Swap the values of two variables
a = 50
b = 100
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 100
# b= 50

# %%
#Store a float value in a variable and print its data type
float = 12.5
print(type(float))
# Out:
# <class 'float'>
